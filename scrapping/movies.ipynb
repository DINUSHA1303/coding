# %%
pip install bs4
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1257 sha256=9402ed343bc5186eb6b76b3d4b425a3becbf1798f5f078765c03782494c63d20
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\25\42\45\b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
#      ---------------------------------------- 62.8/62.8 kB 1.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 140.6/140.6 kB 8.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 61.5/61.5 kB 3.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.imdb.com/list/ls064895701/"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>Top 100 Japanese Movies (IMDB Ratings) - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# </script>
# <link href="https://www.imdb.com/list/ls064895701/" rel="canonical"/>
# ...

# %%
name=soup.select(".lister-item-header a")

# %%
name
# Out:
# [<a href="/title/tt0245429/">Sen to Chihiro no kamikakushi</a>,
#  <a href="/title/tt0119698/">Mononoke-hime</a>,
#  <a href="/title/tt0347149/">Hauru no ugoku shiro</a>,
#  <a href="/title/tt0047478/">Shichinin no samurai</a>,
#  <a href="/title/tt0096283/">Tonari no Totoro</a>,
#  <a href="/title/tt0095327/">Hotaru no haka</a>,
#  <a href="/title/tt5311514/">Kimi no Na wa.</a>,
#  <a href="/title/tt0266308/">Batoru rowaiaru</a>,
#  <a href="/title/tt0094625/">Akira</a>,
#  <a href="/title/tt0087544/">Kaze no tani no Naushika</a>,
#  <a href="/title/tt0042876/">Rashômon</a>,
#  <a href="/title/tt0092067/">Tenkû no shiro Rapyuta</a>,
#  <a href="/title/tt0113568/">Kôkaku Kidôtai</a>,
#  <a href="/title/tt0097814/">Majo no takkyûbin</a>,
#  <a href="/title/tt0876563/">Gake no ue no Ponyo</a>,
#  <a href="/title/tt0089881/">Ran</a>,
#  <a href="/title/tt0055630/">Yôjinbô</a>,
#  <a href="/title/tt1568921/">Karigurashi no Arietty</a>,
#  <a href="/title/tt0104652/">Kurenai no buta</a>,
# ...

# %%
rating=soup.select(".ipl-rating-star.small")

# %%
rating
# Out:
# [<div class="ipl-rating-star small">
#  <span class="ipl-rating-star__star">
#  <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <path d="M0 0h24v24H0z" fill="none"></path>
#  <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z"></path>
#  <path d="M0 0h24v24H0z" fill="none"></path>
#  </svg>
#  </span>
#  <span class="ipl-rating-star__rating">8.6</span>
#  </div>,
#  <div class="ipl-rating-star small">
#  <span class="ipl-rating-star__star">
#  <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <path d="M0 0h24v24H0z" fill="none"></path>
#  <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z"></path>
#  <path d="M0 0h24v24H0z" fill="none"></path>
#  </svg>
#  </span>
#  <span class="ipl-rating-star__rating">8.4</span>
#  </div>,
# ...

# %%
import pandas

# %%
import pandas as pd

# %%
movielist=pd.DataFrame(name,columns=["list"])

# %%
movielist
# Out:
#                                list
# 0     Sen to Chihiro no kamikakushi
# 1                     Mononoke-hime
# 2              Hauru no ugoku shiro
# 3              Shichinin no samurai
# 4                  Tonari no Totoro
# ..                              ...
# 95                Aruitemo aruitemo
# 96  Kumo no mukô, yakusoku no basho
# 97              Kamera o tomeru na!
# 98                 Tekkon kinkurîto
# 99               Hotarubi no mori e
#
# [100 rows x 1 columns]

# %%
directors=soup.select(".text-muted a:nth-child(1)")

# %%
directors
# Out:
# [<a href="/name/nm0594503/">Hayao Miyazaki</a>,
#  <a href="/name/nm0594503/">Hayao Miyazaki</a>,
#  <a href="/name/nm0594503/">Hayao Miyazaki</a>,
#  <a href="/name/nm0000041/">Akira Kurosawa</a>,
#  <a href="/name/nm0594503/">Hayao Miyazaki</a>,
#  <a href="/name/nm0847223/">Isao Takahata</a>,
#  <a href="/name/nm1396121/">Makoto Shinkai</a>,
#  <a href="/name/nm0297935/">Kinji Fukasaku</a>,
#  <a href="/name/nm0960028/">Katsuhiro Ôtomo</a>,
#  <a href="/name/nm0594503/">Hayao Miyazaki</a>,
#  <a href="/name/nm0000041/">Akira Kurosawa</a>,
#  <a href="/name/nm0594503/">Hayao Miyazaki</a>,
#  <a href="/name/nm0651900/">Mamoru Oshii</a>,
#  <a href="/name/nm0594503/">Hayao Miyazaki</a>,
#  <a href="/name/nm0594503/">Hayao Miyazaki</a>,
#  <a href="/name/nm0000041/">Akira Kurosawa</a>,
#  <a href="/name/nm0000041/">Akira Kurosawa</a>,
#  <a href="/name/nm0948488/">Hiromasa Yonebayashi</a>,
#  <a href="/name/nm0594503/">Hayao Miyazaki</a>,
# ...

# %%
movielist["director"]=directors

# %%
movielist
# Out:
#                                list            director
# 0     Sen to Chihiro no kamikakushi    [Hayao Miyazaki]
# 1                     Mononoke-hime    [Hayao Miyazaki]
# 2              Hauru no ugoku shiro    [Hayao Miyazaki]
# 3              Shichinin no samurai    [Akira Kurosawa]
# 4                  Tonari no Totoro    [Hayao Miyazaki]
# ..                              ...                 ...
# 95                Aruitemo aruitemo  [Hirokazu Koreeda]
# 96  Kumo no mukô, yakusoku no basho    [Makoto Shinkai]
# 97              Kamera o tomeru na!  [Shin'ichirô Ueda]
# 98                 Tekkon kinkurîto     [Michael Arias]
# 99               Hotarubi no mori e    [Takahiro Ômori]
#
# [100 rows x 2 columns]

# %%
movielist.to_csv("D:\java/japanesemovie.csv")

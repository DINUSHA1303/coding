# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np

# %%
import pandas as pd

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
D=pd.read_csv("C:/Users/ADMIN/Downloads/Admission_Predict_Ver1.1 (1).csv")

# %%
D
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1              0.92
# ...

# %%
D.shape
# Out:
# (500, 9)

# %%
D.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
nd=D.drop(['Serial No.','TOEFL Score','University Rating','SOP','LOR','CGPA','Research'],axis=1)

# %%
nd
# Out:
#      GRE Score  Chance of Admit
# 0          337              0.92
# 1          324              0.76
# 2          316              0.72
# 3          322              0.80
# 4          314              0.65
# ..         ...               ...
# 495        332              0.87
# 496        337              0.96
# 497        330              0.93
# 498        312              0.73
# 499        327              0.84
#
# [500 rows x 2 columns]

# %%
x=nd.iloc[:,0].values.reshape(-1,1)

# %%
y=nd.iloc[:,0].values.reshape(-1,1)

# %%
x
# Out:
# array([[337],
#        [324],
#        [316],
#        [322],
#        [314],
#        [330],
#        [321],
#        [308],
#        [302],
#        [323],
#        [325],
#        [327],
#        [328],
#        [307],
#        [311],
#        [314],
#        [317],
#        [319],
#        [318],
#        [303],
#        [312],
#        [325],
#        [328],
#        [334],
#        [336],
#        [340],
#        [322],
#        [298],
#        [295],
#        [310],
#        [300],
#        [327],
#        [338],
#        [340],
#        [331],
#        [320],
#        [299],
#        [300],
#        [304],
#        [307],
#        [308],
#        [316],
#        [313],
#        [332],
#        [326],
#        [322],
#        [329],
#        [339],
#        [321],
#        [327],
#        [313],
#        [312],
#        [334],
#        [324],
#        [322],
#        [320],
#        [316],
#        [298],
#        [300],
#        [311],
#        [309],
#        [307],
# ...

# %%
y
# Out:
# array([[337],
#        [324],
#        [316],
#        [322],
#        [314],
#        [330],
#        [321],
#        [308],
#        [302],
#        [323],
#        [325],
#        [327],
#        [328],
#        [307],
#        [311],
#        [314],
#        [317],
#        [319],
#        [318],
#        [303],
#        [312],
#        [325],
#        [328],
#        [334],
#        [336],
#        [340],
#        [322],
#        [298],
#        [295],
#        [310],
#        [300],
#        [327],
#        [338],
#        [340],
#        [331],
#        [320],
#        [299],
#        [300],
#        [304],
#        [307],
#        [308],
#        [316],
#        [313],
#        [332],
#        [326],
#        [322],
#        [329],
#        [339],
#        [321],
#        [327],
#        [313],
#        [312],
#        [334],
#        [324],
#        [322],
#        [320],
#        [316],
#        [298],
#        [300],
#        [311],
#        [309],
#        [307],
# ...

# %%
pt.scatter(x,y)
pt.xlabel("GRE SCORE")
pt.ylabel("CHANCE")
pt.title("linear regression")
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,train_size=0.5,random_state=0)

# %%
X_test.shape
# Out:
# (250, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_predict=lm.predict(X_test)

# %%
y_predict
# Out:
# array([[318.],
#        [321.],
#        [321.],
#        [328.],
#        [301.],
#        [314.],
#        [298.],
#        [302.],
#        [297.],
#        [324.],
#        [317.],
#        [320.],
#        [314.],
#        [313.],
#        [334.],
#        [297.],
#        [323.],
#        [317.],
#        [326.],
#        [300.],
#        [295.],
#        [320.],
#        [296.],
#        [331.],
#        [322.],
#        [318.],
#        [325.],
#        [311.],
#        [306.],
#        [304.],
#        [316.],
#        [296.],
#        [301.],
#        [323.],
#        [315.],
#        [298.],
#        [328.],
#        [324.],
#        [300.],
#        [310.],
#        [314.],
#        [329.],
#        [330.],
#        [316.],
#        [327.],
#        [324.],
#        [333.],
#        [326.],
#        [309.],
#        [314.],
#        [306.],
#        [312.],
#        [305.],
#        [325.],
#        [309.],
#        [328.],
#        [295.],
#        [323.],
# ...

# %%
COMP=pd.DataFrame(X_test,columns=['GRE'])

# %%
COMP
# Out:
#      GRE
# 0    318
# 1    321
# 2    321
# 3    328
# 4    301
# ..   ...
# 245  317
# 246  297
# 247  312
# 248  323
# 249  340
#
# [250 rows x 1 columns]

# %%
COMP['CHA']=Y_test

# %%
COMP
# Out:
#      GRE  CHA
# 0    318  318
# 1    321  321
# 2    321  321
# 3    328  328
# 4    301  301
# ..   ...  ...
# 245  317  317
# 246  297  297
# 247  312  312
# 248  323  323
# 249  340  340
#
# [250 rows x 2 columns]

# %%
COMP['PRDDATA']=y_predict

# %%
COMP
# Out:
#      GRE  CHA  PRDDATA
# 0    318  318    318.0
# 1    321  321    321.0
# 2    321  321    321.0
# 3    328  328    328.0
# 4    301  301    301.0
# ..   ...  ...      ...
# 245  317  317    317.0
# 246  297  297    297.0
# 247  312  312    312.0
# 248  323  323    323.0
# 249  340  340    340.0
#
# [250 rows x 3 columns]

# %%
COMP['AVLDATA']=Y_test

# %%
COMP
# Out:
#      GRE  CHA  PRDDATA  AVLDATA
# 0    318  318    318.0      318
# 1    321  321    321.0      321
# 2    321  321    321.0      321
# 3    328  328    328.0      328
# 4    301  301    301.0      301
# ..   ...  ...      ...      ...
# 245  317  317    317.0      317
# 246  297  297    297.0      297
# 247  312  312    312.0      312
# 248  323  323    323.0      323
# 249  340  340    340.0      340
#
# [250 rows x 4 columns]

# %%
nd=D.drop(['Serial No.','GRE Score','TOEFL Score','University Rating','LOR','CGPA','Research'],axis=1)

# %%
nd
# Out:
#      SOP  Chance of Admit
# 0    4.5              0.92
# 1    4.0              0.76
# 2    3.0              0.72
# 3    3.5              0.80
# 4    2.0              0.65
# ..   ...               ...
# 495  4.5              0.87
# 496  5.0              0.96
# 497  4.5              0.93
# 498  4.0              0.73
# 499  4.5              0.84
#
# [500 rows x 2 columns]

# %%
x=nd.iloc[:,0].values.reshape(-1,1)

# %%
x
# Out:
# array([[4.5],
#        [4. ],
#        [3. ],
#        [3.5],
#        [2. ],
#        [4.5],
#        [3. ],
#        [3. ],
#        [2. ],
#        [3.5],
#        [3.5],
#        [4. ],
#        [4. ],
#        [4. ],
#        [3.5],
#        [3.5],
#        [4. ],
#        [4. ],
#        [4. ],
#        [3.5],
#        [3. ],
#        [3. ],
#        [5. ],
#        [5. ],
#        [4. ],
#        [4.5],
#        [4.5],
#        [1.5],
#        [2. ],
#        [1.5],
#        [3. ],
#        [4. ],
#        [3. ],
#        [4. ],
#        [4. ],
#        [5. ],
#        [4. ],
#        [1. ],
#        [3. ],
#        [4. ],
#        [3.5],
#        [2.5],
#        [2.5],
#        [4.5],
#        [4.5],
#        [5. ],
#        [4. ],
#        [4.5],
#        [3.5],
#        [3. ],
#        [2.5],
#        [1.5],
#        [4. ],
#        [4. ],
#        [3. ],
#        [3. ],
#        [2. ],
#        [4. ],
#        [3. ],
#        [2. ],
#        [3. ],
#        [4. ],
# ...

# %%
y=nd.iloc[:,0].values.reshape(-1,1)

# %%
y
# Out:
# array([[4.5],
#        [4. ],
#        [3. ],
#        [3.5],
#        [2. ],
#        [4.5],
#        [3. ],
#        [3. ],
#        [2. ],
#        [3.5],
#        [3.5],
#        [4. ],
#        [4. ],
#        [4. ],
#        [3.5],
#        [3.5],
#        [4. ],
#        [4. ],
#        [4. ],
#        [3.5],
#        [3. ],
#        [3. ],
#        [5. ],
#        [5. ],
#        [4. ],
#        [4.5],
#        [4.5],
#        [1.5],
#        [2. ],
#        [1.5],
#        [3. ],
#        [4. ],
#        [3. ],
#        [4. ],
#        [4. ],
#        [5. ],
#        [4. ],
#        [1. ],
#        [3. ],
#        [4. ],
#        [3.5],
#        [2.5],
#        [2.5],
#        [4.5],
#        [4.5],
#        [5. ],
#        [4. ],
#        [4.5],
#        [3.5],
#        [3. ],
#        [2.5],
#        [1.5],
#        [4. ],
#        [4. ],
#        [3. ],
#        [3. ],
#        [2. ],
#        [4. ],
#        [3. ],
#        [2. ],
#        [3. ],
#        [4. ],
# ...

# %%
pt.scatter(x,y)
pt.xlabel("GRE SCORE")
pt.ylabel("CHANCE")
pt.title("linear regression")
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,train_size=0.5,random_state=0)

# %%
X_test.shape
# Out:
# (250, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_predict=lm.predict(X_test)

# %%
y_predict
# Out:
# array([[4. ],
#        [4. ],
#        [2.5],
#        [4.5],
#        [2.5],
#        [3.5],
#        [1.5],
#        [4. ],
#        [1.5],
#        [3. ],
#        [2.5],
#        [3. ],
#        [2. ],
#        [4. ],
#        [4. ],
#        [2.5],
#        [4. ],
#        [2. ],
#        [3. ],
#        [1. ],
#        [2.5],
#        [3.5],
#        [2.5],
#        [5. ],
#        [5. ],
#        [2.5],
#        [3. ],
#        [1. ],
#        [3. ],
#        [2.5],
#        [2. ],
#        [3. ],
#        [2.5],
#        [4. ],
#        [2. ],
#        [2.5],
#        [4.5],
#        [4.5],
#        [3.5],
#        [2. ],
#        [2.5],
#        [4. ],
#        [4. ],
#        [3.5],
#        [3. ],
#        [4. ],
#        [5. ],
#        [3.5],
#        [2.5],
#        [4. ],
#        [2.5],
#        [2.5],
#        [2.5],
#        [3. ],
#        [3.5],
#        [4. ],
#        [2.5],
#        [4. ],
#        [3. ],
#        [3. ],
#        [3. ],
#        [5. ],
# ...

# %%
COMP=pd.DataFrame(X_test,columns=['TOFEL'])

# %%
COMP
# Out:
#      TOFEL
# 0      4.0
# 1      4.0
# 2      2.5
# 3      4.5
# 4      2.5
# ..     ...
# 245    3.0
# 246    2.5
# 247    2.5
# 248    4.0
# 249    4.0
#
# [250 rows x 1 columns]

# %%
COMP['CHA']=Y_test

# %%
COMP
# Out:
#      TOFEL  CHA
# 0      4.0  4.0
# 1      4.0  4.0
# 2      2.5  2.5
# 3      4.5  4.5
# 4      2.5  2.5
# ..     ...  ...
# 245    3.0  3.0
# 246    2.5  2.5
# 247    2.5  2.5
# 248    4.0  4.0
# 249    4.0  4.0
#
# [250 rows x 2 columns]

# %%
COMP['PRDDATA']=y_predict

# %%
COMP
# Out:
#      TOFEL  CHA  PRDDATA
# 0      4.0  4.0      4.0
# 1      4.0  4.0      4.0
# 2      2.5  2.5      2.5
# 3      4.5  4.5      4.5
# 4      2.5  2.5      2.5
# ..     ...  ...      ...
# 245    3.0  3.0      3.0
# 246    2.5  2.5      2.5
# 247    2.5  2.5      2.5
# 248    4.0  4.0      4.0
# 249    4.0  4.0      4.0
#
# [250 rows x 3 columns]

# %%
COMP['AVLDATA']=Y_test

# %%
COMP
# Out:
#      TOFEL  CHA  PRDDATA  AVLDATA
# 0      4.0  4.0      4.0      4.0
# 1      4.0  4.0      4.0      4.0
# 2      2.5  2.5      2.5      2.5
# 3      4.5  4.5      4.5      4.5
# 4      2.5  2.5      2.5      2.5
# ..     ...  ...      ...      ...
# 245    3.0  3.0      3.0      3.0
# 246    2.5  2.5      2.5      2.5
# 247    2.5  2.5      2.5      2.5
# 248    4.0  4.0      4.0      4.0
# 249    4.0  4.0      4.0      4.0
#
# [250 rows x 4 columns]
